# %% [markdown]
# <a href="https://colab.research.google.com/github/mdzubayereashraf/Ostad-AI-Engineering-Class-Code-Practices/blob/main/Ostad_AI_Engineering_Class_Code_Practice_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **`Table of Contents`**
# - Introduction to Functions
# - Parameters & Arguments
# - Return values
# - Keyword Arguments
# - Variable Scope
# - Error handling(Try and Exception)
# - Built-in Modules

# %% [markdown]
# ## **`Introduction to Functions`**
#
# **A function is a reusable code block that performs a specific task.**
#
# 🧠 Think of it like a machine:
#
# - You give it some input
#
# - It does something
#
# - It gives back output
#
#
# 💡 so, Function is kind of like a machine (let’s say a coffee machine) which can take input (e.g., coffee beans, milk, sugar, etc.), then process it (grind the beans, heat the water, mix everything together), and finally give some output (a cup of coffee).
#
# - In Python, functions are defined using the `def` keyword.
#
# - After def, we write the function name, followed by parentheses `()` and a colon `:`.
#
# - The code inside the function must be `indented (spaced)`.
#
# - Running a function is called `function calling`.
#
# - Basic Syntax
# def function_name():
#     codeblock

# %%
#Creating a function that greets with people.

def greet(name = "Zubayer"): # setting default value of parameters is a must.
  print(f"Hello,{name}.How's going?")

greet()
greet("Sadia")
# Out:
# Hello,Zubayer.How's going?
# Hello,Sadia.How's going?

# %%
#Another example with return value
def greet(name = "Zubayer"):
    print(f"Hello {name}")
    print(f"How are you {name}?")
    return # return function gives access to use the variable outside the function block, but Print doesn't.

greet()
greet("Noman")
# Out:
# Hello Zubayer
# How are you Zubayer?
# Hello Noman
# How are you Noman?

# %% [markdown]
# ## Note: `Print()` function only displays things but returns nothing, whereas `return` function gives you value .
# ## Return Values
#
# A function can send data back to the main program using return.
#
# 📢 Important
# - `print()` only displays output
# - `return` sends data for further processing

# %% [markdown]
# ## Parameters & Arguments
#
# `Parameters` are variables defined inside the function parentheses.
# They act as placeholders so the function can work with different values.
#
# `Arguments` are the actual values you pass into the function when calling it.
#
# #### 📌 Why This Matters
# Parameters allow your functions to work with **dynamic data**, making them flexible and reusable.
#
# #### Example
#
# ```python
# def greet_name(name):
#     print(f"Hello {name}")
# ```
#
# Here:
# - `name` → Parameter
# - It is defined when we create the function.
#
# #### Calling (Running) the Function
# ```python
# greet_name("Sayem")
# greet_name("Shovon")
# ```
#
# Here:
# - `Sayem` and `Shovon` → Arguments
# - These are the real values passed into the function.
#
#
# **Default parameter:** A default parameter is a parameter that already has a value assigned in the function definition.
#
# If you don’t provide a value when calling the function, Python uses the default.
#
# ```python
# # Example
# def greet_name(name="Guest"):
#     print(f"Hello {name}")
#
# greet_name("Sayem")   # Output: Hello Sayem
# greet_name()          # Output: Hello Guest
# ```
#
# - "Sayem" → overrides the default
#
# - No argument → uses "Guest" as the default

# %%
#Making a coffee machine using function.

def coffee_machine(coffee=10 , sugar = 7, milk = 100):
  print(f"Here's your hot coffee with {coffee}gm coffee, {sugar}gm sugar, and {milk}ml milk.\nEnjoy your coffee.")

coffee_machine()
coffee_machine(20,30,500) # you have to put arguments serially.If you forget then use keyword arguments.
coffee_machine(milk = 300, coffee = 25, sugar = 15)

#coffee_machine(20,30,500) is called positional arguments
#coffee_machine(milk = 300, coffee = 25, sugar = 15) is called keyword arguments
# Out:
# Here's your hot coffee with 10gm coffee, 7gm sugar, and 100ml milk.
# Enjoy your coffee.
# Here's your hot coffee with 20gm coffee, 30gm sugar, and 500ml milk.
# Enjoy your coffee.
# Here's your hot coffee with 25gm coffee, 15gm sugar, and 300ml milk.
# Enjoy your coffee.
