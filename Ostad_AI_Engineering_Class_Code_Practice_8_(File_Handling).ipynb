# %% [markdown]
# <a href="https://colab.research.google.com/github/mdzubayereashraf/Ostad-AI-Engineering-Class-Code-Practices/blob/main/Ostad_AI_Engineering_Class_Code_Practice_8_(File_Handling).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # `Table of Contents`
# - Introduction to file
# - Create and write to a file
# - Read content from a file
# - Append content in a file
# - File Handling using Context Manager
# - File handling issues

# %% [markdown]
# ## Introduction to file
#
# #### Why Do We Need Files?
# Imagine:
#
# - Your app closes ❌
# - Variables disappear ❌
# - Data is lost ❌
#
# 👉 Files solve this problem.
#
# ```python
# # Variables are temporary
# user = "Alice"
# print(user)
#
# # After program ends → data gone
# ```
#
# #### Real-World Use Cases
# - Login logs
# - Exam results
# - Contacts
# - Transaction history
#
#
# #### File Handling Basic Syntax
# ```python
# file = open(filepath, mode)
# ```
#
# <div style="display: flex; gap: 20px; align-items: flex-start;">
# <div>
#
# | Mode  | Meaning                  |
# | ----- | ------------------------ |
# | `"r"` | Read (default)           |
# | `"w"` | Write (overwrite)        |
# | `"a"` | Append (add at end)      |
#
# </div>
# </div>

# %% [markdown]
# ##  `Create and write to a file`
# ```python
# file = open(filepath, "w")  # open file in write mode
# file.write("Hello World")
# file.close()     # file must be closed
# ```
# - Write mode (`"w"`) overwrites existing content.
# - If the file does not exist, it will be created

# %%
file = open("/content/drive/MyDrive/File handling/introduction.txt", "w")
file.write("Hello, World.\n")
file.write("I'm mastering Python from zero to hero.")
file.close() # file must be closed
print(file)
# Out:
# <_io.TextIOWrapper name='/content/drive/MyDrive/File handling/introduction.txt' mode='w' encoding='utf-8'>

# %% [markdown]
# ## `Read content from a file`
#
# #### Read entire file
# ```python
# file = open(filepath, "r")  # open file in read mode
# content = file.read()
# print(content)
# file.close()                # file must be closed
# ```
#
# #### read specific numbers of characters
# ```python
# file = open(filepath, "r")
# content = file.read(30)     # reads first 30 characters from the file
# print(content)
# file.close()                # file must be closed
# ```
#
# #### Read All Lines (as a List)
# ```python
# file = open(filepath, "r")
# lines = file.readlines()   # returns a list of lines
# print(lines)               # Example Output: ["line1\n", "line2\n"]
# file.close()               # file must be closed
# ```
#
# #### Read line by line
# ```python
# file = open(filepath, "r")
# for line in file:
#     print(line)                 # you may use print(line.strip()) to remove extra new line character
# file.close()                    # file must be closed
# ```

# %%
file = open("/content/drive/MyDrive/File handling/introduction.txt", "r")
content = file.read()
print(content)
file.close() # file must be closed
# Out:
# Hello, World.
# I'm mastering Python from zero to hero.

# %%
# reads first 5 characters from the file
file = open("/content/drive/MyDrive/File handling/introduction.txt", "r")
content = file.read(5)
print(content)
file.close() # file must be closed
# Out:
# Hello

# %%
# reads first 13 characters from the file
file = open("/content/drive/MyDrive/File handling/introduction.txt", "r")
content = file.read(13)
print(content)
file.close() # file must be closed
# Out:
# Hello, World.

# %%
# reads first 5 characters from the file
file = open("/content/drive/MyDrive/File handling/introduction.txt", "r")
content = file.read(5)
print(content)
file.close() # file must be closed

# %%
# using .readlines() method
file = open("/content/drive/MyDrive/File handling/introduction.txt", "r")
content = file.readlines()
print(content)
file.close() # file must be closed
# Out:
# ['Hello, World.\n', "I'm mastering Python from zero to hero."]

# %% [markdown]
# ## `Append content in a file`
#
# ```python
# file = open(filepath, "a")       # open in append mode
# file.write("New content added")
# file.close()                    # file must be closed
# ```
#
# - Append mode (`"a"`) adds new content at the end of the file.
# - It does NOT overwrite existing content.
# - If the file does not exist, it will be created.

# %%
file = open("/content/drive/MyDrive/File handling/introduction.txt", "a")
file.write("So, Cheer me up.\n")
file.close() # file must be closed
print(file)
# Out:
# <_io.TextIOWrapper name='/content/drive/MyDrive/File handling/introduction.txt' mode='a' encoding='utf-8'>

# %%
file = open("/content/drive/MyDrive/File handling/introduction.txt", "r")
new = file.read()
print(new)
file.close()
# Out:
# Hello, World.
# I'm mastering Python from zero to hero.So, Cheer me up.So, Cheer me up.So, Cheer me up.So, Cheer me up.
# So, Cheer me up.

# %% [markdown]
# ## `File Handling using Context Manager`
#
# Instead of manually closing files, use `with`
#
# ```python
# # writing to a file
# with open(filepath, "w") as file:
#     f.write("Hello World")
#
# # reading from a file
# with open(filepath, "r") as file:
#     content = file.read()
#     print(content)
#
# # appending to a file
# with open(filepath, "a") as file:
#     file.write("New Content")
#     print(content)
# ```
#
# - File is automatically closed. No need to manually close the file.
# - Cleaner and safer code

# %%
with open("/content/drive/MyDrive/File handling/introduction.txt", "w") as file:
  file.write("Hello, World.\n")
  file.write("I'm mastering Python from zero to hero.\n")

print(file)
# Out:
# <_io.TextIOWrapper name='/content/drive/MyDrive/File handling/introduction.txt' mode='w' encoding='utf-8'>

# %%
with open("/content/drive/MyDrive/File handling/introduction.txt", "r") as file:

  print(file.read())
# Out:
# Hello, World.
# I'm mastering Python from zero to hero.

# %%
with open("/content/drive/MyDrive/File handling/introduction.txt", "a") as file:

  file.write("\nSo, cheer me up.\n")

print(file)
# Out:
# <_io.TextIOWrapper name='/content/drive/MyDrive/File handling/introduction.txt' mode='a' encoding='utf-8'>

# %%
with open("/content/drive/MyDrive/File handling/introduction.txt", "r") as file:

  print(file.read())
# Out:
# Hello, World.
# I'm mastering Python from zero to hero.So, cheer me up.
#
# So, cheer me up.

# %% [markdown]
# ## File handling issues
#
# ### `1.` wrong operation mode e.g. trying to read while using write or read mode
#
# ##### Solution: Always choose the correct mode:
#
# - If you want to read → use `"r"`
# - If you want to write → use `"w"`
# - If you want to add → use `"a"`
#
# ### `2.` Accidentally overwriting a file with write mode
#
# Write mode (`"w"`) deletes all previous content before writing.
#
# If `data.txt` already had important data → it is permanently lost.
#
# #### Solution:
# - Use `"a"` (append mode) if you want to keep old data:
#
# - Or check before writing:
# ```python
# import os
#
# if not os.path.exists("data.txt"):
#     with open("data.txt", "w") as file:
#         file.write("\nNew Content")
# ```
# - Or open in `"x"` mode (creates file only if it does NOT exist):
#
# ```python
# with open("data.txt", "x") as file:
#     file.write("Hello World")
# ```

# %%
with open("data.txt", "x") as file:
    file.write("Hello World")  # if data.txt exists, file won't created, will raise an error
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# /tmp/ipykernel_1513/1577575633.py in <cell line: 0>()
# ----> 1 with open("data.txt", "x") as file:
#       2     file.write("Hello World")  # if data.txt exists, file won't created, will raise an error
#
# FileExistsError: [Errno 17] File exists: 'data.txt'
